# %%
from autoviz.AutoViz_Class import AutoViz_Class
from autoviz import data_cleaning_suggestions
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv('.\\Dataset\\data7\\train.csv')

# %%
# verify the data and give some suggestion about cleaning data as it is presented in following report
data_cleaning_suggestions(df)
# Out:
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_aa83c_row0_col0, #T_aa83c_row0_col4, #T_aa83c_row5_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# ...
